# %% [markdown]
# # What is a Unit of observation?
#
# Understanding the Context Behind Numbers

# %% [markdown]
# ## Problem

# %% [markdown]
# ### Situation 1 - Income
#
# Imagine:
#
# 1. You want to study **“income.”**
# 2. You collect numbers: Row 1 = individual? Row 2 = family? Row 3 = household?
#
# You can calculate averages, sums, percentages… but then a question arises:
#
# > What do these numbers really represent?
# > Who or what is each number describing?
#
# At this point, you realize there’s something missing that makes the numbers meaningful. 🔺

# %% [markdown]
# ### Situation 2 — Height
#
# Imagine:
#
# 1. You want to analyze **“height.”**
# 2. You collect measurements: Row 1 = person, Row 2 = building, Row 3 = tree.
#
# You can calculate the average of all these heights, or look at the spread… but then it hits you:
#
# > What does this average actually mean?
# > Which entities are being compared?
#
# Without clarity, the numbers seem disconnected. 🔺

# %% [markdown]
# ### Situation 3 — School Performance
#
# Imagine:
#
# 1. You want to analyze **“school performance.”**
# 2. Rows could represent students, classes, or entire schools.
#
# You try to summarize performance and draw conclusions. Suddenly you wonder:
#
# > Are we comparing individuals, groups, or institutions?
# > Does the measure reflect the level you intended?
#
# The lack of clarity makes any conclusion questionable. 🔺

# %% [markdown]
# 🔹 **Final question of this section:**
#
# > If numbers exist, but we don’t know **who or what they are measured for**, **what gives them comparative meaning?** 🔺
